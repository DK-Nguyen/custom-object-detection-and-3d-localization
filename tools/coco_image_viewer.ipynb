# %%
from coco_image_viewer import CocoDataset
import IPython

annotation_path = './experiments/image_composition/training/coco_instances.json'
image_dir = './experiments/image_composition/training/images'

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
html = coco_dataset.display_image(image_id=1, use_url=False)
IPython.display.HTML(html)
# Out:
# Dataset Info:
# ...
#   description: experiment
#   url: none
#   version: experiment_1.0
#   year: 2021
#   contributor: DK
#   date_created: 03/09/2021
#
# Licenses:
# ...
#   url: none
#   id: 0
#   name: free
#
#
# Categories:
# ...
#   super_category: tree
#     id 1: tree
#
# Image:
# ...
#   license: 0
#   file_name: 00000001.png
#   width: 512
#   height: 512
#   id: 1
#   segmentations (4):
#     12:blue:{'supercategory': 'tree', 'id': 1, 'name': 'tree'}
#     13:purple:{'supercategory': 'tree', 'id': 1, 'name': 'tree'}
#     14:red:{'supercategory': 'tree', 'id': 1, 'name': 'tree'}
#     15:green:{'supercategory': 'tree', 'id': 1, 'name': 'tree'}
# <div class="container" style="position:relative;"><img src="data:image/png;base64,..." style="position:relative;top:0px;left:0px;width:512px;"><div class="svgclass"><svg width="512" height="512.0"><polygon points="201 218 203 213 200 207 199 198 199 158 201 152 201 131 203 126 208  14
# ...

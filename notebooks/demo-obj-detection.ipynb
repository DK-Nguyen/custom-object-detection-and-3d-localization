# %%
import random
from pathlib import Path
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
import cv2
from google.colab.patches import cv2_imshow
from detectron2.data.datasets import register_coco_instances
import logging

PROJECT_PATH = Path('/home/dk/Desktop/projects/customized-object-detection')
# Out:
# /home/dk/Desktop/projects/customized-object-detection/.env-customized-obj-detection/lib/python3.7/site-packages/google/colab/data_table.py:30: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   from IPython.utils import traitlets as _traitlets

# %%
coco_instances_path = PROJECT_PATH / 'datasets/coco_like/training' / 'coco_instances.json'
coco_image_dir = PROJECT_PATH / 'datasets/coco_like/training' / 'images'
register_coco_instances(name='coco_tree_train',
                        metadata={},
                        json_file=coco_instances_path,
                        image_root=coco_image_dir)

# %%
    dataset_dicts = DatasetCatalog.get("coco_tree_train")
    coco_tree_metadata = MetadataCatalog.get("coco_tree_train")
    print(dataset_dicts)
    import random

    for d in random.sample(dataset_dicts, 3):
        img = cv2.imread(d["file_name"])
        visualizer = Visualizer(img[:, :, ::-1], metadata=coco_tree_metadata, scale=0.5)
        vis = visualizer.draw_dataset_dict(d)
        cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FFAEE37D510>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FFAEF3BF4D0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FFAEF722F90>
